# %% [markdown]
# ## Capitulo 1.1: Resumiendo datos categóricos

# %% [markdown]
# ### Caso 1.1: Compañia de Envíos (Parte 1 - Datos Categóricos)

# %% [markdown]
# Imagina que eres el nuevo Analista de Supply Chain de una importante compañía de logística y envíos con cobertura a nivel internacional. La compañía opera fundamentalmente en la mayoría de ciudades de Estados Unidos. Estas asumiendo un cargo nuevo como tomador de decisiones, asi que la primera tarea que te propones es estudiar las instalaciones y la capacidad instalada de la compañía para ir conociendo el terreno. Para esto cuentas con un set de datos que contiene información sobre las instalaciones con las que cuenta la compañía en Estados Unidos. Como buen Analista de Supply Chain tu trabajo será hacer un análisis de datos exploratorio para conocer como se distribuyen las instalaciones, de que tipo son, y cuáles son las ciudades más importantes en términos de la cantidad de instalaciones que poseen.
#
# Tópicos a abordar en este tutorial:
# * Atributos y variables.
# * Tipos de variables.
# * Distribuciones de frecuencia.
#
# Inicialmente deberemos importar las librerias necesarias para realizar nuestro análisis:

# %%
import numpy as np
import pandas as pd
import math

# %% [markdown]
# Luego de importar las librerías procederemos a hacer la lectura de un dataset a un dataframe, el archivo a cargar se denomina 'UPD_INSTALACIONES.csv', el cual es un archivo de tipo '.csv' (Comma Separated Values, o Valores Separados por Comas). Por tanto, para importar este tipo de archivos utilizaremos la librería pandas como 'pd':

# %%
df = pd.read_csv('UPD_INSTALACIONES.csv')
df.head()
# Out:
#            X          Y   FID  FEATURE_ID                       NAME  \
# 0 -75.365329  37.933822  3001       23612           H And H Pharmacy
# 1 -75.831766  37.517799  3002       48000       Nottingham Insurance
# 2 -77.852181  36.752769  3003        2002  The Lawrenceville Profess
# 3 -77.583137  37.443143  3004       47871            Model Realty In
# 4 -76.029401  36.806975  3005        2835             Post Office(r)
#
#            TYPE                  ADDRESS ADDRESS2                 CITY STATE  \
# 0  Self-Service         6300 Maddox Blvd           Chincoteague Island    VA
# 1  Self-Service        4068 Lankford Hwy                        Exmore    VA
# 2  Self-Service           411 S Hicks St                 Lawrenceville    VA
# 3  Self-Service         10132 Hull St Rd                    Midlothian    VA
# 4  Self-Service  Nas Oceana Building 531                Virginia Beach    VA
#
#      ZIP   LATITUDE  LONGITUDE             MATCHSTATU  \
# ...

# %% [markdown]
# Al inspeccionar la cabecera del dataframe nos damos cuenta que el objeto cuenta con un total de 12 atributos o columnas. Realizaremos una inspección inicial del dataframe para conocer los tipos de datos que contiene:

# %%
print(df.dtypes)
# Out:
# X             float64
# Y             float64
# FID             int64
# FEATURE_ID      int64
# NAME           object
# TYPE           object
# ADDRESS        object
# ADDRESS2       object
# CITY           object
# STATE          object
# ZIP             int64
# LATITUDE      float64
# LONGITUDE     float64
# MATCHSTATU     object
# PLACEMENT      object
# CENSUSCODE     object
# NAME0          object
# dtype: object

# %% [markdown]
# El código ejecutado anteriormente nos permite identificar los diferentes tipos de datos que se encuentran almacenados dentro de cada columna. Por lo pronto python solo ha identificado tres (3) tipos de datos dentro del dataframe:
#
# * float64: Se refiere a números fraccionarios o decimales dentro del conjunto de los números reales,
# * int64: Se refiere a números enteros dentro del conjunto de los reales, y
# * object: Se refiere a cualquier valor alfanumérico.
#
# Luego de verificar los contenidos de las columnas, nos damos cuenta que las columnas 'X' y 'Y' tienen el mismo contenido que las columnas 'LONGITUDE' y 'LATITUDE' (Longitud y latitud en español). Respectivamente se puede evidenciar que 'X' corresponde a 'LONGITUDE' y 'Y' corresponde a 'LATITUDE' por tal razón eliminaremos dichas columnas de nuestro dataframe 'df' y el marco de datos resultante se la asignaremos a un nuevo dataframe llamado 'df0':

# %%
df0 = df.drop(['X','Y'], axis=1)
df0.head()
# Out:
#     FID  FEATURE_ID                       NAME          TYPE  \
# 0  3001       23612           H And H Pharmacy  Self-Service
# 1  3002       48000       Nottingham Insurance  Self-Service
# 2  3003        2002  The Lawrenceville Profess  Self-Service
# 3  3004       47871            Model Realty In  Self-Service
# 4  3005        2835             Post Office(r)  Self-Service
#
#                    ADDRESS ADDRESS2                 CITY STATE    ZIP  \
# 0         6300 Maddox Blvd           Chincoteague Island    VA  23336
# 1        4068 Lankford Hwy                        Exmore    VA  23350
# 2           411 S Hicks St                 Lawrenceville    VA  23868
# 3         10132 Hull St Rd                    Midlothian    VA  23112
# 4  Nas Oceana Building 531                Virginia Beach    VA  23460
#
#     LATITUDE  LONGITUDE             MATCHSTATU  \
# 0  37.933822 -75.365329                     OK
# 1  37.517799 -75.831766                     OK
# ...

# %% [markdown]
# Posterior a esto podemos notar en el dataframe que la columna 'FID' cuenta con el id de la instalación, este id es único para cada instalación registrada en el dataframe. Sin embargo, es evidente que la tabla no se encuentra organizada por el 'FID' en orden ascendente, ya que el primer registro de 'FID' es 3001, y sabemos por experiencia previa que son en total 48821 instalaciones. Procederemos a ordenar el dataframe por la columna 'FID' de forma ascendente:

# %%
df0 = df0.sort_values(by='FID', ascending=True)
df0.head()
# Out:
#       FID  FEATURE_ID                       NAME                    TYPE  \
# 1000    1       28379  Universal Blueprint Paper            Self-Service
# 1001    2       28380              Suntrust Bank            Self-Service
# 1002    3       28385             Post Office(r)            Self-Service
# 1003    4       28387      Dcm Travel & Shipping  Authorized Ship Center
# 1004    5       28388              Colonial Bank            Self-Service
#
#                    ADDRESS ADDRESS2   CITY STATE    ZIP   LATITUDE  LONGITUDE  \
# 1000        1803 E 2nd Ave           Tampa    FL  33605  27.956644 -82.439072
# 1001        601 W Platt St           Tampa    FL  33606  27.941708 -82.465888
# 1002    5206 N Florida Ave           Tampa    FL  33603  27.994389 -82.459439
# 1003  8338 N Armenia Ave S    Ste A  Tampa    FL  33604  28.024894 -82.484288
# 1004    4144 N Armenia Ave           Tampa    FL  33607  27.976984 -82.484789
#
#      MATCHSTATU PLACEMENT       CENSUSCODE  \
# ...

# %%
df0.tail()
# Out:
#          FID  FEATURE_ID             NAME                    TYPE  \
# 48816  48817       25990            FedEx                 Staffed
# 48817  48818       25991         Key Bank            Self-Service
# 48818  48819       25992      Goin Postal  Authorized Ship Center
# 48819  48820       25995      Shop N Save            Self-Service
# 48820  48821       26003  Paper Signs Ink  Authorized Ship Center
#
#                  ADDRESS ADDRESS2          CITY STATE   ZIP   LATITUDE  \
# 48816      975 Skyway St           Presque Isle    ME  4769  46.699644
# 48817  State and Main St           Presque Isle    ME  4769  46.681196
# 48818        26 North St           Presque Isle    ME  4769  46.688198
# 48819        114 High St                Caribou    ME  4736  46.860595
# 48820     32 W Main St S  Ste 101     Fort Kent    ME  4743  47.250349
#
#        LONGITUDE    MATCHSTATU PLACEMENT       CENSUSCODE  \
# 48816 -68.026354            OK            230039520001000
# ...

# %% [markdown]
# Notamos como la tabla se ha reordenado por la columna 'FID' en forma ascendente, y, por otro lado, se ha desordenado el índice pues ahora inicia en 1000 y no en 0. Por tal motivo procederemos a eliminar este índice que no tiene significado alguno y utilizaremos la columna 'FID' como el nuevo índice de la tabla:

# %%
df0 = df0.set_index('FID')
df0.head()
# Out:
#      FEATURE_ID                       NAME                    TYPE  \
# FID
# 1         28379  Universal Blueprint Paper            Self-Service
# 2         28380              Suntrust Bank            Self-Service
# 3         28385             Post Office(r)            Self-Service
# 4         28387      Dcm Travel & Shipping  Authorized Ship Center
# 5         28388              Colonial Bank            Self-Service
#
#                   ADDRESS ADDRESS2   CITY STATE    ZIP   LATITUDE  LONGITUDE  \
# FID
# 1          1803 E 2nd Ave           Tampa    FL  33605  27.956644 -82.439072
# 2          601 W Platt St           Tampa    FL  33606  27.941708 -82.465888
# 3      5206 N Florida Ave           Tampa    FL  33603  27.994389 -82.459439
# 4    8338 N Armenia Ave S    Ste A  Tampa    FL  33604  28.024894 -82.484288
# 5      4144 N Armenia Ave           Tampa    FL  33607  27.976984 -82.484789
#
#     MATCHSTATU PLACEMENT       CENSUSCODE  \
# FID
# ...

# %% [markdown]
# Ya el dataframe va quedando como queremos para empezar a desarrollar el análisis. Ahora hemos decidido solamente reducir el dataframe, y solo quedarnos con las columnas que serán la entrada para el análisis. Las columnas a utilizar para el análisis serán: 'TYPE', 'CITY', 'STATE', 'ZIP', 'LATITUDE', y 'LONGITUDE'.

# %%
df0 = df0[['TYPE','CITY','STATE','ZIP','LATITUDE','LONGITUDE']]
df0.head()
# Out:
#                        TYPE   CITY STATE    ZIP   LATITUDE  LONGITUDE
# FID
# 1              Self-Service  Tampa    FL  33605  27.956644 -82.439072
# 2              Self-Service  Tampa    FL  33606  27.941708 -82.465888
# 3              Self-Service  Tampa    FL  33603  27.994389 -82.459439
# 4    Authorized Ship Center  Tampa    FL  33604  28.024894 -82.484288
# 5              Self-Service  Tampa    FL  33607  27.976984 -82.484789

# %%
path = "UPDI_CLEAN.csv"
df0.to_csv(path)

# %% [markdown]
# Ahora si el dataframe ha quedado listo para realizar el análisis exploratorio. Inicialmente realizaremos una tabla de frecuencias agrupada para cada variable: Tipo de instalación, ciudad, estado, código postal, latitud y longitud.

# %% [markdown]
# ### Tipos de variables y tablas de frecuencia:

# %% [markdown]
# Las tablas de frecuencias agrupadas son útiles para resumir grandes conjuntos de datos y ver cómo se distribuyen datos entre las diferentes categorías o intervalos determinados para cada variable. Inicialmente tenemos que saber que existen dos (2) grandes tipos de variables:
#
# * __Cualitativa o categórica:__ Este tipo de variable es tal que sus valores no se pueden asociar naturalmente a un número, y por ende no se pueden realizar operaciones algebraicas con ellos, pero si se pueden definir categorías porque representan una característica de la población estudiada. Dentro de las variables cualitativas encontramos:
#     * __Variables nominales:__ Cuyos valores no se pueden ordenar, solamente se pueden categorizar. Por ejemplo: Sexo, grupo sanguíneo, religión, o nacionalidad.
#     * __Variables ordinales:__ Cuyos valores se pueden ordenar según una escala definida. Por ejemplo: grado de satisfacción, intensidad del dolor, grado académico.
# * __Cuantitativa o numérica__: Como su nombre lo indica, los valores que puede tomar este tipo de variable se asocian naturalmente a un número, y por ende se pueden realizar operaciones algebraicas con ellos. Entre las variables cuantitativas están:
#     * __Variables discretas:__ Las cuales solamente toma valores enteros y por lo general expresan el conteo de un número finito de instancias o valores de una variable. Por ejemplo: número de integrantes en la familia, cantidad de cigarrillos fumados, número de cumpleaños que ha tenido una persona, etc.
#     * __Variables continuas:__ Estas variables existen cuando entre dos valores que toma la variable, existe un número infinito de valores intermedios que también podría tener la variable. Por ejemplo: altura, dosis de un medicamento administrado, edad, etc.
#
# __Nota__: La edad de una persona, animal o cosa, a diferencia del número de cumpleaños, es una variable continua porque entre cualquier par de valores de edad existe un número infinito de valores posibles. Por ejemplo: Entre la edad de 18 y la edad de 19 años existen un número infinito de edades que puede tener determinada persona: 18.2, 18.23, 18.234, 18.2345, 18.6, 18.67, 18.678, etc...
#
# En este caso de estudio examinaremos cada una de las variables representadas por los atributos del dataframe y realizaremos una tabla de frecuencias con base al tipo de variable encontrada, iniciaremos con las variables cualitativas o categóricas.

# %% [markdown]
# #### Variable cualitativa - Tipo de instalación:

# %% [markdown]
# El tipo de instalación es una variable categórica pues los valores que contiene no se pueden ordenar por su naturaleza ni permiten realizar operaciones algebráicas, esta variable se encuentra representada por la columna 'TYPE' en el dataframe. A continuación, examinaremos cuántos tipos de instalaciones existen y la cantidad de instalaciones existentes de cada tipo. Partiremos agrupando el dataframe por el tipo de instalación ('TYPE'), así:

# %% [markdown]
# 1. Se toman dos (2) columnas de 'df0', la primera columna será 'TYPE' y la segunda columna puede ser cualquiera pues esta columna almacenará el conteo del número de casos que ocurren por cada tipo, en este caso utilizaremos la columna 'CITY'. Posteriormente, en la misma línea de código se agrupa el dataframe por la columna 'TYPE' con el comando '.groupby()', luego se utiliza el método agregado '.count()' para contar las instancias en cada categoría encontrada y finalmente se le asigna dichas modificaciones del dataframe 'df0' a una nueva vista del dataframe que llamamos 'df0_gbtype':

# %%
df0_gbtype = df0[['TYPE','CITY']].groupby('TYPE').count()

# %% [markdown]
# 2. Se crea una nueva columna denominada 'fi' que indica la frecuencia absoluta de cada categoría determinada, es decir, el número total de casos encontrados en cada categoría y se le asignan los valores de la columna 'CITY':

# %%
df0_gbtype['fi'] = df0_gbtype['CITY']

# %% [markdown]
# 3. Se elimina la columna 'CITY' del nuevo dataframe y el resultado es nuestra tabla de frecuencias inicial:

# %%
df0_gbtype = df0_gbtype.drop(['CITY'], axis = 1)
df0_gbtype
# Out:
#                            fi
# TYPE
# Authorized Ship Center   7411
# Self-Service            39426
# Staffed                  1984

# %% [markdown]
# Una vez agrupados los datos y definida nuestra tabla inicial podemos decir que existen tres (3) tipos de instalaciones en la compañía:
#
# * __Centro de Envíos Autorizado (Authorized Ship Center)__, de la cuál existen 7.411 locaciones.
# * __Autoservicio (Self-Service)__, 39.426 locaciones.
# * __Con personal (Staffed)__, 1.984 locaciones.
#
# Si sumamos los valores de la tabla debería dar en total 48.821, que es el número total de registros (instalaciones) que hay en el set de datos que importamos:

# %%
gbtype_total = np.sum(df0_gbtype['fi'])
gbtype_total
# Out:
# 48821

# %% [markdown]
# Habiendo confirmado que el valor total coincide con el total de registros de la tabla. Lo siguiente que será necesario hacer es crear una columna nombrada 'hi' que indica la frecuencia relativa de cada categoría determinada, es decir, el porcentaje de casos encontrados en cada categoría con respecto al total de casos:

# %%
df0_gbtype['hi'] = round(df0_gbtype['fi']/gbtype_total,2)
df0_gbtype
# Out:
#                            fi    hi
# TYPE
# Authorized Ship Center   7411  0.15
# Self-Service            39426  0.81
# Staffed                  1984  0.04

# %% [markdown]
# De lo anterior podemos concluir que el tipo de instalación más común en la compañía es el 'Self-Service' donde se reportan un total de 39.426 locaciones repartidas a lo ancho y largo de Estados Unidos, representa el 81% de total de instalaciones con la que cuenta la compañía. Por otro lado, el tipo de instalación menos común es 'Staffed' con 1.984 casos en total repartidos a lo largo y ancho de Estados Unidos, representa el 4% del total de instalaciones de la compañía. El restante 15%, aproximadamente 7.411 instalaciones corresponden al tipo de Centro de Envíos Autorizado. Por lo anterior podemos suponer que la compañía ofrece principalmente instalaciones de Autoservicio: casilleros e infraestructura para entrega y consignación autónoma de paquetería. En segundo plano están las operaciones de los Centros de Envíos Autorizados que son tiendas independientes de la compañía que ofrecen servicios similares, y en último lugar están las oficinas Con personal, que ofrecen atención directa de los empleados al usuario.

# %% [markdown]
# #### Variable Cualitativa - Estado:

# %% [markdown]
# De la misma forma se realiza el proceso de manipulación del dataframe para obtener la frecuencia absoluta y la frecuencia relativa del número de instalaciones existentes en cada uno de los estados listados en el dataframe, específicamente en la columna 'STATE'. Iniciamos con la agrupación de la columna 'TYPE' teniendo como referencia la columna 'STATE' y posteriormente se calcula la frecuencia absoluta a través del método agregado '.count()' así:

# %%
df0_gbs = df0[['TYPE','STATE']].groupby(['STATE']).count()
df0_gbs['fi'] = df0_gbs['TYPE']
df0_gbs = df0_gbs.drop(['TYPE'], axis = 1)
df0_gbs.head(10)
# Out:
#          fi
# STATE
# AK       51
# AL      661
# AR      388
# AZ      863
# CA     6074
# CO     1106
# CT      709
# DC      264
# DE      134
# FL     3943

# %% [markdown]
# Nótese que se imprimieron en total 10 filas, esto es debido a que la función '.head()' se utilizó introduciendo como argumento el número 10 para que retornara las primeras 10 filas del dataframe '.head(10)', dado que en realidad son 51 categorías o estados resultantes (todas las jurisdicciones de Estados Unidos) como se puede observar a continuación:

# %%
df0_gbs.nunique()
# Out:
# fi    51
# dtype: int64

# %% [markdown]
# A continuación, procedemos a confirmar la frecuencia absoluta total a través de la suma de los valores de la columna 'fi':

# %%
gbs_total = np.sum(df0_gbs['fi'])
gbs_total
# Out:
# 48821

# %% [markdown]
# Ahora si podemos crear la columna de frecuencia relativa ('hi') para determinar el porcentaje de participación de cada estado en el número de instalaciones que tiene la compañía:

# %%
df0_gbs['hi'] = round(df0_gbs['fi']/gbs_total,3)
df0_gbs.head(10)
# Out:
#          fi     hi
# STATE
# AK       51  0.001
# AL      661  0.014
# AR      388  0.008
# AZ      863  0.018
# CA     6074  0.124
# CO     1106  0.023
# CT      709  0.015
# DC      264  0.005
# DE      134  0.003
# FL     3943  0.081

# %% [markdown]
# Teniendo la frecuencia absoluta y la frecuencia relativa de los estados podemos organizar la tabla de tal forma que se muestren los 10 primeros estados por cantidad de instalaciones asignadas de la siguiente forma: Se utilizó el método '.sort_values()' donde se introdujeron dos (2) argumentos: la columna que definirá el orden de la tabla, es decir 'fi', y si deseamos que se ordene de mayor a menor deberemos utilizar el argumento 'ascending' e igualarlo a 'False'. Con esto le indicamos al programa que deberá ordenarlos de forma descendente como en el ejemplo.

# %%
df0_gbs = df0_gbs.sort_values(by=['fi'],ascending=False)
df0_gbs.head(10)
# Out:
#          fi     hi
# STATE
# CA     6074  0.124
# TX     4156  0.085
# FL     3943  0.081
# NY     2412  0.049
# IL     2141  0.044
# NJ     2097  0.043
# PA     1945  0.040
# GA     1880  0.039
# NC     1594  0.033
# MA     1550  0.032

# %% [markdown]
# Dado que las instalaciones se encuentran distribuidas en todas las provincias de Estados Unidos se podría determinar qué porcentaje de las instalaciones corresponde a los primeros 10 estados calculando la frecuencia absoluta acumulada ('Fi') y la frecuencia relativa acumulada ('Hi') utilizando el método '.cumsum()' así:

# %%
df0_gbs['Fi'] = df0_gbs['fi'].cumsum()
df0_gbs['Hi'] = df0_gbs['hi'].cumsum()
df0_gbs.head(10)
# Out:
#          fi     hi     Fi     Hi
# STATE
# CA     6074  0.124   6074  0.124
# TX     4156  0.085  10230  0.209
# FL     3943  0.081  14173  0.290
# NY     2412  0.049  16585  0.339
# IL     2141  0.044  18726  0.383
# NJ     2097  0.043  20823  0.426
# PA     1945  0.040  22768  0.466
# GA     1880  0.039  24648  0.505
# NC     1594  0.033  26242  0.538
# MA     1550  0.032  27792  0.570

# %% [markdown]
# Con este ejercicio ya somos capaces de decir que los primeros diez (10) estados para la compañía en términos de cantidad de instalaciones son los siguientes: 'CA' - California, 'TX' - Texas, 'FL' - Florida, 'NY' - Nueva York, 'IL' - Illinois, 'NL' - Nueva Jersey, 'PA' - Pensilvania, 'GA' - Georgia, 'NC' - Carolina del Norte y 'MA' - Massachusetts. Cada uno con un total de: 6.074, 4.156, 3.943, 2.412, 2.141, 2.097, 1.945, 1.880, 1.594, y 1.550 instalaciones respectivamente. Para un total acumulado de 27.792 instalaciones que están localizadas en las jurisdicciones de dichos estados, representando aproximadamente un total de 57% de las instalaciones de la compañía.

# %% [markdown]
# Si quisiéramos conocer la cantidad de instalaciones que se encuentran localizadas en una provincia específica, por ejemplo Wyoming ('WY'), solamente deberemos utilizar la propiedad '.loc[ ]' así:

# %%
df0_gbs.loc['WY', ['fi']]
# Out:
# fi    126.0
# Name: WY, dtype: float64

# %% [markdown]
# Esta propiedad permite consultar un registro en específico dentro del dataframe, como no se conoce exactamente la posición del estado de Wyoming en el dataframe, procedimos a utilizar la propiedad '.loc[]' donde los argumentos introducidos fueron:
#
# * El registro o fila específica que deseamos: 'WY', y
# * El atributo o variable determinado que queremos consultar: 'fi'.
#
# Ahora ya sabemos que existen 126 instalaciones en el estado de Wyoming. Así mismo, otra propiedad útil que se podría utilizar cuando se conoce la posición del registro dentro de la tabla es '.iloc[]', así:

# %%
WY_idx = df0_gbs.index.get_loc('WY')
df0_gbs.iloc[WY_idx,[0]]
# Out:
# fi    126.0
# Name: WY, dtype: float64

# %% [markdown]
# Lo que acabamos de realizar fue conseguir la localización del índice 'WY' por su nombre utilizando la función '.index.get_loc()' sobre el dataframe y dicho valor se lo asignamos a la variable 'WY_idx'. Posteriormente utilizamos la propiedad '.iloc[]' introduciendo dos (2) argumentos:
#
# * La localización del índice almacenado en la variable 'WY_idx', y
# * La localización numérica de la columna 'fi'.
#
# Con esto ya somos capaces de realizar consultas para ver la cantidad de instalaciones en determinada provincia utilizando las propiedades '.loc[]' y 'iloc[]'.
